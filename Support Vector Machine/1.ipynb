# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# تولید داده‌های تفکیک‌پذیر خطی
np.random.seed()
X = np.r_[np.random.randn(200, 2) - [4, 4], np.random.randn(200, 2) + [4, 4]]
Y = [0] * 200 + [1] * 200

# ایجاد مدل SVM با هسته خطی
clf = svm.SVC(kernel='poly')

# آموزش مدل
clf.fit(X, Y)

# تصویرسازی نتایج
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired, marker='o')

# رسم مرز تصمیم
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# ایجاد مشبک نقطه‌ها برای پیش‌بینی
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 50),
                     np.linspace(ylim[0], ylim[1], 50))
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# رسم مرز تصمیم و همچنین خطوط حاشیه
ax.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import svm

# تولید داده‌های غیرخطی
X, y = datasets.make_circles(n_samples=200, noise=0.08, random_state=42)

# ایجاد مدل SVM با هسته گاوسی (RBF)
clf = svm.SVC(kernel='rbf', C=1)

# آموزش مدل
clf.fit(X, y)

# تصویرسازی نتایج
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, marker='o')

# رسم مرز تصمیم
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# ایجاد مشبک نقطه‌ها برای پیش‌بینی
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 100),
                     np.linspace(ylim[0], ylim[1], 100))
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# رسم مرز تصمیم و همچنین خطوط حاشیه
ax.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
plt.show()

# %%
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt

# داده‌های تصادفی
np.random.seed(0)
X = np.random.randn(300, 2)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# ایجاد یک مدل SVM با کرنل خطی
clf = svm.SVC(kernel='rbf', C=1)
clf.fit(X, y)

# تصویرسازی نتایج
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, marker='o')

# رسم مرز تصمیم
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# تعیین محدوده‌ی داده‌ها برای نمایش
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# پیش‌بینی برچسب‌ها برای نقاط مختلف
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# نمایش خط مربوط به مارجین
ax.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
plt.show()

# %%
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt

# داده‌های تصادفی
np.random.seed(0)
X = np.random.randn(300, 2)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# اضافه کردن نویز به برچسب‌ها
random_noise = np.random.normal(0, 0.9, 300)
y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0) ^ (random_noise > 0.5)

# ایجاد یک مدل SVM با کرنل خطی
clf = svm.SVC(kernel='linear', C=8)
clf.fit(X, y)

# تصویرسازی نتایج
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, marker='o')

# رسم مرز تصمیم
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# تعیین محدوده‌ی داده‌ها برای نمایش
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# پیش‌بینی برچسب‌ها برای نقاط مختلف
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# نمایش خط مربوط به مارجین
ax.contour(xx, yy, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
plt.show()
